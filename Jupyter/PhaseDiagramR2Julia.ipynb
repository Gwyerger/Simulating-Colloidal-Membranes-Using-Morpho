# %%
using Plots

# %% [markdown]
# # Creating a Phase Diagram in Julia

# %%
# We devise a PVPython script that tells us the existance of a pore.
# The data we receive is in a text document of the form bool.

path = "C:\\Users\\gabey\\OneDrive\\Desktop\\Fall 2023\\SM Research\\Phase Diagram VTK Exports and PP\\Single Pore Round 2\\"
name1 = "IsPoreData.txt"
delimiter = ","
pop = "\n"
file = open(path*name1, "r")
strdata = readlines(file)

PoreTruex = []
PoreFalsex = []
PoreMaybex = []
PoreTruey = []
PoreFalsey = []
PoreMaybey = []
for line in strdata[begin+1:1:end]
    line = replace(line, pop => "")
    line = split(line, delimiter)
    line = [parse(Float64, line[1]), parse(Float64, line[2]), line[3] ]
    if occursin("None", line[3])
        push!(PoreMaybex, line[2])
        push!(PoreMaybey, line[1])
    else
        if occursin("True", line[3])
            push!(PoreTruex, line[2])
            push!(PoreTruey, line[1])
        elseif occursin("False", line[3])
            push!(PoreFalsex, line[2])
            push!(PoreFalsey, line[1])
        end
    end
end

print(PoreMaybex)
# Out:
# Any[70.0, 75.0, 80.0, 85.0, 90.0, 95.0, 100.0, 105.0, 110.0, 55.0, 60.0, 65.0, 70.0, 75.0, 80.0, 85.0, 90.0, 95.0, 100.0, 105.0, 110.0, 115.0, 120.0, 125.0, 50.0, 55.0, 60.0, 115.0, 120.0, 125.0, 130.0, 135.0, 130.0, 135.0, 140.0, 145.0, 140.0, 145.0, 150.0, 145.0, 150.0]

# %%
plt = scatter(PoreTruex/100,PoreTruey/100, label="Stable", markerstrokecolor="limegreen", markercolor="limegreen", markershape=:circle)
scatter!(plt, PoreMaybex/100, PoreMaybey/100, label="Shrunken", markerstrokecolor="maroon1", markercolor="maroon1", markershape=:circle)
scatter!(plt, PoreFalsex/100,PoreFalsey/100, label="Unstable", markerstrokecolor="dodgerblue2", markercolor="dodgerblue2", markershape=:circle)
plot!(plt,title = "Pore Stability-Phase Diagram",minorgrid=true,legend=:outerbottom, legendcolumns=3, xlabel="qλ", ylabel="γλ/K", dpi=400)

# %%
savefig(path*"PD.png")
# Out:
# "C:\\Users\\gabey\\OneDrive\\Desktop\\Fall 2023\\SM Research\\Phase Diagram VTK Exports and PP\\Single Pore Round 2\\PD.png"
